# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
print ("Environment in fact works!")
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Environment in fact works!

# %%
import goatools
print ("Goatools is in fact installed")
# Out:
# Goatools is in fact installed
